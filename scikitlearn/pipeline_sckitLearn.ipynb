# %% [markdown]
# # Let's Code - Criação de um pipeline dentro do Sklearn:
#
#
# - O que é um pipeline?
# - Quais as vantagens de se utilizar um pipeline?
# - E o pipeline dentro do contexto de ciência de dados?
#     - Feature normalization
#     - Feature selection
#     - Treinando e avaliando modelos em Pipelines
#         - Cross Validation em Pipelines
#         - Grid-Search com Pipelines
#     - Visualizando o pipeline
# - O pipeline em aplicação no dia-a-dia do cientista de dados
#
#
#
# ## O que é um pipeline?
#
#
# Um pipeline (em tradução livre uma sequência de canos conectados) é uma sequência de funções conectadas que ao final nos dá um resultado esperado.
#
# Considere o exemplo abaixo onde várias funções estão sendo aplicadas sob uma string:

# %% [markdown]
# #### Exemplo 1: Implementação sem pipes

# %%
import numpy as np

# %%
string = "O rato roeu a roupa do rei de roma"

# deixa tudo como letra minuscula
string = string.lower()

# substitui a palavra rato por rata
string = string.replace("rato", "rata")

# substitui rei por rainha
string = string.replace("rei", "rainha")

# substitui o por a
string = string.replace("o ", "a ")

# substitui "do" por "da"
string = string.replace("do", "da")

# deixa a primeira letra maiúscula
string = string.capitalize()
print(string)
# Out:
# A rata roeu a roupa da rainha de roma

# %% [markdown]
# #### Como podemos melhorar o código acima?

# %%
string = "O rato roeu a roupa do rei de roma"

string = string.lower()

replace = {"rato": "rata", "rei": "rainha", "o ": "a ", "do": "da"}

for original, replacer in replace.items():
    
    string = string.replace(original, replacer)

string = string.capitalize()

# %% [markdown]
# #### Exemplo 3: Utilizando funções customizadas

# %%
def to_str(value):
    
    return str(value) + " é a resposta para tudo"

# %%
string = to_str(42)

# todas as palavras com a primeira letra maiuscula
string = string.title()

# RESPOSTA agora é toda maiúscula
string = string.replace("Resposta", "RESPOSTA")

# %% [markdown]
# #### Exemplo 4: Pipeline com funções customizadas

# %%
to_str(42).title().replace("Resposta", "RESPOSTA")
# Out:
# '42 É A RESPOSTA Para Tudo'

# %% [markdown]
# ## Quais as vantagens de se utilizar um pipeline?
#
# Os códigos acima são exemplos básicos da utilização de um pipeline. Dentro de códigos pequenos talvez não seja possível ver tanta a necessidade da utilização de pipes em funções, entretanto, em grandes projetos que exigem muitas linhas de código de dedicação esse tipo de técnica se torna indispensável. <br>
#
# Assim as principais vantagens de se utilizar um pipeline são:
#
# - Aumento na legibilidade de código
# - Aumento na reproductibilidade dos resultados
#
#
# Entretanto, vale ressaltar, que o uso excessivo de pipes pode atrapalhar um pouco na legibilidade. Vai do bom senso do profissional ver até que ponto o uso trás benefícios pra legibilidade do código.

# %% [markdown]
# ## E o pipeline dentro do contexto de ciência de dados?
#
# O pipeline em aprendizado de máquina foi introduzido pela biblioteca Sklearn com o objetivo de aumentar a legibilidade de código evitando a reutilização excessiva de variáveis. Outro ponto é a reproductibilidade dos experimentos e sistemas que são feitos com base em modelos do Sklearn
#
# <br>
#
# Para colocar tudo isso que nós vimos em prática, vamos passar por um stack completo de operações utilizando o pipeline. As operações que serão realizadas são:
#
# - Feature Normalization
# - Feature Selection
# - Grid Search
# - Cross-Validation
#
# Para este exemplo vamos utilizar os dados do dataset heart disease: <b><a href="https://www.kaggle.com/ronitf/heart-disease-uci">Heart Disease</a></b>. O objetivo neste dataset é predizer se um paciente possui uma doença cardíaca ou não.

# %%
import pandas as pd

import numpy as np

# %%
df = pd.read_table("Data/heart.csv", sep=',')

# %%
df
# Out:
#      age sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63   M   3       145   233    1        0      150      0      2.3
# 1     37   M   2       130   250    0        1      187      0      3.5
# 2     41   F   1       130   204    0        0      172      0      1.4
# 3     56   M   1       120   236    0        1      178      0      0.8
# 4     57   F   0       120   354    0        1      163      1      0.6
# ..   ...  ..  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57   F   0       140   241    0        1      123      1      0.2
# 299   45   M   3       110   264    0        1      132      0      1.2
# 300   68   M   0       144   193    1        1      141      0      3.4
# 301   57   M   0       130   131    0        1      115      1      1.2
# 302   57   F   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
df.describe()
# Out:
#               age          cp    trestbps        chol         fbs     restecg  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.966997  131.623762  246.264026    0.148515    0.528053
# std      9.082101    1.032052   17.538143   51.830751    0.356198    0.525860
# min     29.000000    0.000000   94.000000  126.000000    0.000000    0.000000
# 25%     47.500000    0.000000  120.000000  211.000000    0.000000    0.000000
# 50%     55.000000    1.000000  130.000000  240.000000    0.000000    1.000000
# 75%     61.000000    2.000000  140.000000  274.500000    0.000000    1.000000
# max     77.000000    3.000000  200.000000  564.000000    1.000000    2.000000
#
#           thalach       exang     oldpeak       slope          ca        thal  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   149.646865    0.326733    1.039604    1.399340    0.729373    2.313531
# std     22.905161    0.469794    1.161075    0.616226    1.022606    0.612277
# min     71.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%    133.500000    0.000000    0.000000    1.000000    0.000000    2.000000
# 50%    153.000000    0.000000    0.800000    1.000000    0.000000    2.000000
# 75%    166.000000    1.000000    1.600000    2.000000    1.000000    3.000000
# max    202.000000    1.000000    6.200000    2.000000    4.000000    3.000000
#
#            target
# count  303.000000
# mean     0.544554
# std      0.498835
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %% [markdown]
# Como podemos ver na tabela acima, temos como grande maioria <b>variáveis númericas contínuas</b>, a variável target é o que queremos predizer e a variável <b>sex</b> é uma variável categórica no tipo <b>string</b>.
#
# <br>
#
# <b>Dado que valores muito discrepantes podem ter um impacto muito grande no modelo iremos:</b>
#
# - Normalizar as variáveis contínuas
#
# <b>Dado que modelos do Sklearn só aceitam variáveis númericas temos que:</b>
#
# - Categorizar a variável do tipo string para valor númerico
#
# <b>Dado que nem todas as features auxiliam na predição do modelo:</b>
#
# - Seleção das K melhores features
#
# <b>Dado que temos que garantir a validade estatística dos nossos algoritmos:</b>
#
# - K-Fold
#
# <b>Dado que temos que queremos ter o melhor algoritmo possível:</b>
#
# - GridSearch

# %% [markdown]
# Resumo de algumas funções que utilizaremos
#
# <img src="Figures/cross_validation.png">
# <center><b>Relembrando: Validação Cruzada</b></center>
#
#
# <img src="Figures/f1.jpeg">
# <center><b>Relembrando: F1-Score</b></center>
#
#
# <img src="Figures/Precisão_e_revocação.png" width=400 heigth=400>
# <center><b>Relembrando: F1 Score é a combinação das métricas de precisão e revocação</b></center>

# %%
from sklearn.pipeline import Pipeline

# %% [markdown]
# <b> Primeiramente vamos importar a função de <b>Pipeline</b> do sklearn.</b>

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, mutual_info_classif

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder

from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer
from sklearn.metrics import f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, mutual_info_classif

# %%
df_aux = df.copy()

imputer = SimpleImputer(strategy='most_frequent')

all_columns = list(df_aux.drop(['target'], axis=1).columns)

df_aux[all_columns] = imputer.fit_transform(df_aux[all_columns])

encoding = LabelEncoder()

df_aux['sex'] = encoding.fit_transform(df_aux['sex'])

# z = (x - u) / s
# Remove a variância da média
normalization = StandardScaler()

df_aux[all_columns] = normalization.fit_transform(df_aux.drop(['target'], axis=1))

model = RandomForestClassifier()

# # definindo 5 folds em que os dados vão ser divididos
kfold = KFold(n_splits=5, shuffle=True)

# # Realiza a valiação cruzada dos resultados e 
# # nos dá como retorno os resultados de cada um dos folds
scoring = make_scorer(f1_score)

results = cross_validate(model, X=df_aux.drop(['target'], axis=1), y=df_aux['target'], cv=kfold, scoring=scoring)

# %% [markdown]
# <b>Sem pipeline</b>

# %%
df_aux = df.copy()

imputer = SimpleImputer(strategy='most_frequent')

all_columns = list(df_aux.drop(['target'], axis=1).columns)

df_aux[all_columns] = imputer.fit_transform(df_aux[all_columns])

encoding = LabelEncoder()

df_aux['sex'] = encoding.fit_transform(df_aux['sex'])

# z = (x - u) / s
# Remove a variância da média
normalization = StandardScaler()

df_aux[all_columns] = normalization.fit_transform(df_aux.drop(['target'], axis=1))

model = RandomForestClassifier()

# # definindo 5 folds em que os dados vão ser divididos
kfold = KFold(n_splits=5, shuffle=True)

# # Realiza a valiação cruzada dos resultados e 
# # nos dá como retorno os resultados de cada um dos folds
scoring = make_scorer(f1_score)

results = cross_validate(model, X=df_aux.drop(['target'], axis=1), y=df_aux['target'], cv=kfold, scoring=scoring)

# %%
# criando o pipeline

# cada passo é declarado como um dupla
# o primeiro valor descreve qual operação será aplicada
# o segundo valor possui a função que vai ser aplicada sobre os dados
# vale ressaltar que o segundo valor pode ser uma função personalizada
# desde que o modelo possua as funções fit, transform


df_aux = df.drop(['sex'], axis=1)

model = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('normalization', StandardScaler()),
    ('model', RandomForestClassifier())
])


# definindo 5 folds em que os dados vão ser divididos
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Realiza a valiação cruzada dos resultados e 
# nos dá como retorno os resultados de cada um dos folds
sg = make_scorer(f1_score)

results = cross_validate(model, X=df_aux.drop(['target'], axis=1), y=df_aux['target'], cv=kfold, scoring=sg)

# %% [markdown]
# <b>Modelo simples sem a variável sexo</b>

# %% [markdown]
# <b>Modelo simples com a variável sexo</b>

# %%
imputer = Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent'))])

encoding = Pipeline(steps=[('encoding', OneHotEncoder())])

normalization = Pipeline(steps=[('normalization', StandardScaler())])

pre_processing = ColumnTransformer(transformers=[
                                                    ('cat', encoding, ['sex']),
                                                    ('normalization', normalization, list(df.drop(['sex', 'target'], axis=1).columns)),
                                                    ('imputer', imputer, list(df.drop(['sex', 'target'], axis=1).columns))
                                                ])

model = Pipeline(steps=[
    ('pre processing', pre_processing),
    ('model', RandomForestClassifier())
])


# definindo 5 folds em que os dados vão ser divididos
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Realiza a valiação cruzada dos resultados e 
# nos dá como retorno os resultados de cada um dos folds
scoring = make_scorer(f1_score)

results = cross_validate(model, X=df.drop(['target'], axis=1), y=df['target'], cv=kfold, scoring=scoring)

# %% [markdown]
# <b>Modelo simples com a variável sexo</b>

# %%
imputer = Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent'))])

encoding = Pipeline(steps=[('encoding', OneHotEncoder())])

normalization = Pipeline(steps=[('normalization', StandardScaler())])

pre_processing = ColumnTransformer(transformers=[
                                                    ('cat', encoding, ['sex']),
                                                    ('normalization', normalization, list(df.drop(['sex', 'target'], axis=1).columns)),
                                                    ('imputer', imputer, list(df.drop(['sex', 'target'], axis=1).columns))
                                                ])

model = Pipeline(steps=[
    ('pre processing', pre_processing),
    ('model', RandomForestClassifier())
])


# definindo 5 folds em que os dados vão ser divididos
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Realiza a valiação cruzada dos resultados e 
# nos dá como retorno os resultados de cada um dos folds
scoring = make_scorer(f1_score)

results = cross_validate(model, X=df.drop(['target'], axis=1), y=df['target'], cv=kfold, scoring=scoring)

# %%
"F1-Score - Mean: ", np.mean(results['test_score']), " Std. Dev ", np.std(results['test_score'])
# Out:
# ('F1-Score - Mean: ', 0.8277704259042729, ' Std. Dev ', 0.03140316907378237)

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Grid Search com pipelines

# %%
model = Pipeline(steps=[
    ('pre processing', pre_processing),
    ('feature-selection', SelectKBest(mutual_info_classif, k = 10)),
    ('model', RandomForestClassifier())
])

# %%
# Parâmetros que serão explorados
parameters = {'model__max_depth': [3, 4, 5], 'model__criterion': ['gini', 'entropy'],
              'model__n_estimators': [50, 100, 200]}



kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Identifica os melhores parâmetros
grid = GridSearchCV(model, param_grid=parameters, cv=kfold, n_jobs=-1)

# %%
from sklearn import set_config

# %%
result = grid.fit(X=df.drop(['target'], axis=1), y=df['target'])

# os melhores parâmetros
print(grid.cv_results_)
# Out:
# {'mean_fit_time': array([0.61168041, 0.85586705, 1.43369036, 0.62425489, 0.91315827,
#        1.42289705, 0.65052152, 0.81536303, 1.59029441, 0.54441118,
#        0.83891263, 1.41301098, 0.54306092, 0.85080886, 1.39686551,
#        0.63139997, 0.94073043, 1.35391431]), 'std_fit_time': array([0.15026489, 0.15832707, 0.16792075, 0.12370889, 0.08767346,
#        0.1561126 , 0.10202413, 0.15419864, 0.30631617, 0.10832436,
#        0.1963884 , 0.22336445, 0.05920661, 0.19830678, 0.15548187,
#        0.11786565, 0.0931329 , 0.36185592]), 'mean_score_time': array([0.05051942, 0.06687574, 0.1254426 , 0.05601273, 0.07593894,
#        0.10215774, 0.05595064, 0.0757153 , 0.12029252, 0.04807901,
#        0.06488028, 0.11164613, 0.0446424 , 0.06434999, 0.11589646,
#        0.05161915, 0.06606574, 0.08182831]), 'std_score_time': array([0.01326989, 0.01536339, 0.03418682, 0.01963976, 0.0120756 ,
#        0.03120902, 0.0108959 , 0.01800043, 0.01283599, 0.01354053,
#        0.02252115, 0.03169701, 0.013537  , 0.02068995, 0.04652651,
#        0.0221662 , 0.02806591, 0.03804467]), 'param_model__criterion': masked_array(data=['gini', 'gini', 'gini', 'gini', 'gini', 'gini', 'gini',
#                    'gini', 'gini', 'entropy', 'entropy', 'entropy',
#                    'entropy', 'entropy', 'entropy', 'entropy', 'entropy',
#                    'entropy'],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_model__max_depth': masked_array(data=[3, 3, 3, 4, 4, 4, 5, 5, 5, 3, 3, 3, 4, 4, 4, 5, 5, 5],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'param_model__n_estimators': masked_array(data=[50, 100, 200, 50, 100, 200, 50, 100, 200, 50, 100, 200,
#                    50, 100, 200, 50, 100, 200],
#              mask=[False, False, False, False, False, False, False, False,
#                    False, False, False, False, False, False, False, False,
#                    False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'model__criterion': 'gini', 'model__max_depth': 3, 'model__n_estimators': 50}, {'model__criterion': 'gini', 'model__max_depth': 3, 'model__n_estimators': 100}, {'model__criterion': 'gini', 'model__max_depth': 3, 'model__n_estimators': 200}, {'model__criterion': 'gini', 'model__max_depth': 4, 'model__n_estimators': 50}, {'model__criterion': 'gini', 'model__max_depth': 4, 'model__n_estimators': 100}, {'model__criterion': 'gini', 'model__max_depth': 4, 'model__n_estimators': 200}, {'model__criterion': 'gini', 'model__max_depth': 5, 'model__n_estimators': 50}, {'model__criterion': 'gini', 'model__max_depth': 5, 'model__n_estimators': 100}, {'model__criterion': 'gini', 'model__max_depth': 5, 'model__n_estimators': 200}, {'model__criterion': 'entropy', 'model__max_depth': 3, 'model__n_estimators': 50}, {'model__criterion': 'entropy', 'model__max_depth': 3, 'model__n_estimators': 100}, {'model__criterion': 'entropy', 'model__max_depth': 3, 'model__n_estimators': 200}, {'model__criterion': 'entropy', 'model__max_depth': 4, 'model__n_estimators': 50}, {'model__criterion': 'entropy', 'model__max_depth': 4, 'model__n_estimators': 100}, {'model__criterion': 'entropy', 'model__max_depth': 4, 'model__n_estimators': 200}, {'model__criterion': 'entropy', 'model__max_depth': 5, 'model__n_estimators': 50}, {'model__criterion': 'entropy', 'model__max_depth': 5, 'model__n_estimators': 100}, {'model__criterion': 'entropy', 'model__max_depth': 5, 'model__n_estimators': 200}], 'split0_test_score': array([0.83606557, 0.86885246, 0.86885246, 0.83606557, 0.85245902,
#        0.86885246, 0.83606557, 0.85245902, 0.85245902, 0.83606557,
#        0.83606557, 0.86885246, 0.86885246, 0.83606557, 0.83606557,
#        0.85245902, 0.80327869, 0.85245902]), 'split1_test_score': array([0.80327869, 0.80327869, 0.78688525, 0.78688525, 0.80327869,
#        0.81967213, 0.7704918 , 0.7704918 , 0.78688525, 0.80327869,
#        0.80327869, 0.78688525, 0.80327869, 0.78688525, 0.80327869,
#        0.7704918 , 0.80327869, 0.78688525]), 'split2_test_score': array([0.80327869, 0.80327869, 0.80327869, 0.7704918 , 0.81967213,
#        0.80327869, 0.7704918 , 0.78688525, 0.78688525, 0.7704918 ,
#        0.81967213, 0.80327869, 0.78688525, 0.7704918 , 0.75409836,
#        0.78688525, 0.80327869, 0.75409836]), 'split3_test_score': array([0.73333333, 0.76666667, 0.73333333, 0.78333333, 0.76666667,
#        0.78333333, 0.78333333, 0.75      , 0.73333333, 0.73333333,
#        0.75      , 0.76666667, 0.71666667, 0.75      , 0.81666667,
#        0.78333333, 0.73333333, 0.78333333]), 'split4_test_score': array([0.88333333, 0.88333333, 0.86666667, 0.85      , 0.85      ,
#        0.83333333, 0.86666667, 0.86666667, 0.9       , 0.85      ,
#        0.86666667, 0.86666667, 0.86666667, 0.85      , 0.9       ,
#        0.83333333, 0.88333333, 0.86666667]), 'mean_test_score': array([0.81185792, 0.82508197, 0.81180328, 0.80535519, 0.8184153 ,
#        0.82169399, 0.80540984, 0.80530055, 0.81191257, 0.79863388,
#        0.81513661, 0.81846995, 0.80846995, 0.79868852, 0.82202186,
#        0.80530055, 0.80530055, 0.80868852]), 'std_test_score': array([0.04900625, 0.04398225, 0.05121662, 0.03155263, 0.03182824,
#        0.02889341, 0.03903353, 0.04604051, 0.05801869, 0.04270204,
#        0.03872293, 0.04188859, 0.05648645, 0.03830106, 0.04747926,
#        0.03175874, 0.04749876, 0.04330283]), 'rank_test_score': array([ 8,  1,  9, 13,  5,  3, 12, 15,  7, 18,  6,  4, 11, 17,  2, 15, 14,
#        10], dtype=int32)}

# %%
set_config(display='diagram')

# %%
from sklearn.utils import estimator_html_repr
from IPython.display import HTML

# %%
with open('my_estimator.html', 'w') as f:

    f.write(estimator_html_repr(model))

# %%
HTML('my_estimator.html')
# Out:
# <style>#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 {color: black;background-color: white;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 pre{padding: 0;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-toggleable {background-color: white;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 label.sk-toggleable__label {cursor: pointer;display: block;width: 100%;margin-bottom: 0;padding: 0.2em 0.3em;box-sizing: border-box;text-align: center;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-toggleable__content {max-height: 0;max-width: 0;overflow: hidden;text-align: left;background-color: #f0f8ff;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-toggleable__content pre {margin: 0.2em;color: black;border-radius: 0.25em;background-color: #f0f8ff;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 input.sk-toggleable__control:checked~div.sk-toggleable__content {max-height: 200px;max-width: 100%;overflow: auto;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-estimator input.sk-toggleable__control:checked~label.sk-toggleable__label {background-color: #d4ebff;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-label input.sk-toggleable__control:checked~label.sk-toggleable__label {background-color: #d4ebff;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 input.sk-hidden--visually {border: 0;clip: rect(1px 1px 1px 1px);clip: rect(1px, 1px, 1px, 1px);height: 1px;margin: -1px;overflow: hidden;padding: 0;position: absolute;width: 1px;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-estimator {font-family: monospace;background-color: #f0f8ff;margin: 0.25em 0.25em;border: 1px dotted black;border-radius: 0.25em;box-sizing: border-box;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-estimator:hover {background-color: #d4ebff;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-parallel-item::after {content: "";width: 100%;border-bottom: 1px solid gray;flex-grow: 1;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-label:hover label.sk-toggleable__label {background-color: #d4ebff;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-serial::before {content: "";position: absolute;border-left: 1px solid gray;box-sizing: border-box;top: 2em;bottom: 0;left: 50%;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-serial {display: flex;flex-direction: column;align-items: center;background-color: white;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-item {z-index: 1;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-parallel {display: flex;align-items: stretch;justify-content: center;background-color: white;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-parallel-item {display: flex;flex-direction: column;position: relative;background-color: white;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-parallel-item:first-child::after {align-self: flex-end;width: 50%;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-parallel-item:last-child::after {align-self: flex-start;width: 50%;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-parallel-item:only-child::after {width: 0;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-dashed-wrapped {border: 1px dashed gray;margin: 0.2em;box-sizing: border-box;padding-bottom: 0.1em;background-color: white;position: relative;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-label label {font-family: monospace;font-weight: bold;background-color: white;display: inline-block;line-height: 1.2em;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-label-container {position: relative;z-index: 2;text-align: center;}#sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50 div.sk-container {display: inline-block;position: relative;}</style><div id="sk-3d4d9d00-179e-4e88-a267-4db4c0bbcb50" class"sk-top-container"><div class="sk-container"><div class="sk-item sk-dashed-wrapped"><div class="sk-label-container"><div class="sk-label sk-toggleable"><input class="sk-toggleable__control sk-hidden--visually" id="fde755df-1c81-4597-975b-41e9e684ac9f" type="checkbox" ><label class="sk-toggleable__label" for="fde755df-1c81-4597-975b-41e9e684ac9f">Pipeline</label><div class="sk-toggleable__content"><pre>Pipeline(steps=[('pre  ...
#                  ColumnTransformer(transformers=[('cat',
#                                                   Pipeline(steps=[('encoding',
#                                                                    OneHotEncoder())]),
#                                                   ['sex']),
#                                                  ('normalization',
#                                                   Pipeline(steps=[('normalization',
#                                                                    StandardScaler())]),
#                                                   ['age', 'cp', 'trestbps',
#                                                    'chol', 'fbs', 'restecg',
#                                                    'thalach', 'exang',
#                                                    'oldpeak', 'slope', 'ca',
#                                                    'thal']),
#                                                  ('imputer',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent'))]),
#                                                   ['age', 'cp', 'trestbps',
#                                                    'chol', 'fbs', 'restecg',
#                                                    'thalach', 'exang',
#                                                    'oldpeak', 'slope', 'ca',
#                                                    'thal'])])),
#                 ('feature-selection',
#                  SelectKBest(score_func=<function mutual_info_classif at 0x7f8dc1be7620>)),
#                 ('model', RandomForestClassifier())])</pre></div></div></div><div class="sk-serial"><div class="sk-item sk-dashed-wrapped"><div class="sk-label-container"><div class="sk-label sk-toggleable"><input class="sk-toggleable__control sk-hidden--visually" id="84d7fda1-ca05-4a86-88a9-1c12ead32f56" type="checkbox" ><label class="sk-toggleable__label" for="84d7fda1-ca05-4a86-88a9-1c12ead32f56">pre processing: ColumnTransformer</label><div class="sk-toggleable__content"><pre>ColumnTransformer(transformers=[('cat',
#                                  Pipeline(steps=[('encoding',
#                                                   OneHotEncoder())]),
#                                  ['sex']),
#                                 ('normalization',
#                                  Pipeline(steps=[('normalization',
#                                                   StandardScaler())]),
#                                  ['age', 'cp', 'trestbps', 'chol', 'fbs',
#                                   'restecg', 'thalach', 'exang', 'oldpeak',
#                                   'slope', 'ca', 'thal']),
#                                 ('imputer',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent'))]),
#                                  ['age', 'cp', 'trestbps', 'chol', 'fbs',
#                                   'restecg', 'thalach', 'exang', 'oldpeak',
#                                   'slope', 'ca', 'thal'])])</pre></div></div></div><div class="sk-parallel"><div class="sk-parallel-item"><div class="sk-item"><div class="sk-label-container"><div class="sk-label sk-toggleable"><input class="sk-toggleable__control sk-hidden--visually" id="ba9f3583-0a63-4e37-81b9-ae1a4a96ff34" type="checkbox" ><label class="sk-toggleable__label" for="ba9f3583-0a63-4e37-81b9-ae1a4a96ff34">cat</label><div class="sk-toggleable__content"><pre>['sex']</pre></div></div></div><div class="sk-serial"><div class="sk-item"><div class="sk-serial"><div class="sk-item"><div class="sk-estimator sk-toggleable"><input class="sk-toggleable__control sk-hidden--visually" id="e4b1dd6e-c681-44b3-a21b-c9cf9476c5d3" type="checkbox" ><label class="sk-toggleable__label" for="e4b1dd6e-c681-44b3-a21b-c9cf9476c5d3">OneHotEncoder</label><div class="sk-toggleable__content"><pre>OneHotEncoder()</pre
